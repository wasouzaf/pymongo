# %%
import pymongo
from pymongo import MongoClient

# %%
# !python --version
# Out:
# Python 3.8.3

# %%
# !pip install pymongo[srv]
# Out:
# Requirement already satisfied: pymongo[srv] in c:\users\familia\anaconda3\lib\site-packages (3.11.0)
# Requirement already satisfied: dnspython<2.0.0,>=1.16.0 in c:\users\familia\anaconda3\lib\site-packages (from pymongo[srv]) (1.16.0)

# %%
pymongo.version
# Out:
# '3.11.0'

# %%
client = pymongo.MongoClient("mongodb+srv://Waldeir:waldeir123@cluster0.flgv8.mongodb.net/test")

# %%
client.list_database_names()
# Out:
# ['Anatel', 'admin', 'local']

# %%
db = client.Anatel

db.Anatel
# Out:
# Collection(Database(MongoClient(host=['cluster0-shard-00-00.flgv8.mongodb.net:27017', 'cluster0-shard-00-01.flgv8.mongodb.net:27017', 'cluster0-shard-00-02.flgv8.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, authsource='admin', replicaset='atlas-at8c18-shard-0', ssl=True), 'Anatel'), 'Anatel')

# %%
# 1. Quantos documentos possui a coleção minas?
db.Minas.count_documents({})
# Out:
# 508706

# %%
# 2. Mostre os 5 primeiros documentos da coleção.
list(db.Minas.find().limit(5))
# Out:
# [{'_id': ObjectId('5fb316828be90417282b109f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 12},
#  {'_id': ObjectId('5fb316828be90417282b109d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b109b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 9},
#  {'_id': ObjectId('5fb316828be90417282b10a0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10a8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1}]

# %%
# 3. Selecione o documento que possui o maior número de solicitações QtdeSolic na Anatel.
from bson.son import SON
import pprint
parametro = [ {"$group": { "_id": "null", "maxQuantity": {"$max": "$QtdeSolic"}  } }]
pprint.pprint(list(db.Minas.aggregate(parametro)))
# Out:
# [{'_id': 'null', 'maxQuantity': 4164}]

# %%
#4 - Qual é o menor número de solicitações QtdeSolic na Anatel?
parametro = [ {"$group": { "_id": "null", "minQuantity": {"$min": "$QtdeSolic"}  } }]
pprint.pprint(list(db.minas.aggregate(parametro)))
# Out:
# []

# %%
#5 - Mostre todos os documentos com o menor número de solicitações QtdeSolic na Anatel.
list(db.Minas.find({'QtdeSolic': 1}))
# Out:
# [{'_id': ObjectId('5fb316828be90417282b109d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10a0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10a8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10b1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Resposta de solicitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1095'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10a1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10cc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1099'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10b3'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio Comunitária',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Licenciamento e instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10c5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10cb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10ab'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Telefone de Uso Público - TUP',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10b7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10d1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10a5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10be'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10ca'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1096'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10b4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1097'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10a2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10b9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10ac'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Laudo técnico',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1098'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Atendimento Pessoal ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10cf'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10d4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10e8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Denúncia',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'RTV (Retransmissão de TV)',
#   'Motivo': 'Interferência',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1142'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b114d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1193'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10d7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10fa'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radioamador (PY)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Licença / Autorização',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1126'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10df'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1129'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b113b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10e9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1149'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10ed'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b114a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b115b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1173'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Interrupções no Serviço de Localidades',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b117b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b112e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b117f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1186'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10f9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Rádio do Cidadão (PX)',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10fd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1101'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1107'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1112'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b112d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11a1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Elogio',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11ce'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10de'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10f0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11a0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1100'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b111c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1122'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1135'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'GVT',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11c0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10f1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Legislação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1130'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1138'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1154'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1156'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Internacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1166'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1127'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b113c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1172'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b117c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11d0'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1102'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b110a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11be'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10d6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10f5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1111'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1118'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Promoções',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1167'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Área de Cobertura',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1104'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b116b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Dados cadastrais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10d8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10f8'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Prestadoras',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10fc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1176'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Provedor de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10fe'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1108'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Consulta Pública',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b111f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b112b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'CLARO',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b114b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11c1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1113'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Certificação/Homologação',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1123'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Atendimento',
#   'Motivo': 'Atuação da Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1197'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11b5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b110d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1134'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'EMBRATEL',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b114e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b115f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Clonagem',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11bb'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Serviços Adicionais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11bd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Longa Distância Nacional',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b10f6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1109'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Regulamentação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b110b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Limitado Privado',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b110c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1125'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1136'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Elogio',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1151'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1163'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1170'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Tarifas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11b1'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11fe'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'SKY',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1234'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1242'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Sugestão',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11fd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'SKY',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b120d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b122e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b1245'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Inclusão no SPC/Serasa',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b11e5'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316828be90417282b120e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 1,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
# ...
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1699'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b16b9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Antenas/ERBs',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b16d7'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Cartão pré-pago',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b16d9'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'Outros',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b16dd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b16ec'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Código de acesso',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b170c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio FM',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1713'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Contrato de prestação de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1727'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b172b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Mudança de endereço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1750'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b179e'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17ae'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Planos de serviço',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17ba'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reaberta',
#   'GrupoEconNorm': 'TIM',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Desbloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17c4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio Comunitária',
#   'Motivo': 'Licenciamento e instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17c6'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17e2'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'TV',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17f4'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1820'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pós-Pago',
#   'Motivo': 'Habilitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17fd'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Intelig',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outros',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1808'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Bloqueio',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1816'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'VIVO',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1860'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Portal Anatel',
#   'Motivo': 'Link Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b182f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1846'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b185d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Portal Anatel',
#   'Motivo': 'Link Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1859'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Reclamação',
#   'Servico': 'Radiodifusão (Rádio e TV)',
#   'Modalidade': 'Rádio Comunitária',
#   'Motivo': 'Licenciamento e instalação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17fe'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Reparo',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1800'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'NET',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Programação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b17fc'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Sugestão',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Portal Anatel',
#   'Motivo': 'Link Anatel',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b180a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Códigos não-geográficos',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b180b'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Completamento de Chamadas',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b184a'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço de Rede e Transporte de Telecomunicações - SRTT',
#   'Modalidade': 'NÃO APLICÁVEL',
#   'Motivo': 'Outorga',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1833'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Transferência de titularidade',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1841'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Móvel Pessoal',
#   'Modalidade': 'Pré-Pago',
#   'Motivo': 'Atendimento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b184f'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Lista telefônica',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1862'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'BLUE',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cancelamento',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1810'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 2,
#   'CanalEntrada': 'Fale Conosco        ',
#   'Condicao': 'Reencaminhada',
#   'GrupoEconNorm': 'OI',
#   'Tipo': 'Reclamação',
#   'Servico': 'TV por Assinatura',
#   'Modalidade': 'TV a Cabo',
#   'Motivo': 'Cobrança',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b182c'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'ALGAR',
#   'Tipo': 'Reclamação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Auxílio à Lista',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b184d'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviço Telefônico Fixo Comutado - STFC',
#   'Modalidade': 'Local',
#   'Motivo': 'Instalação de Acessos Individuais',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  {'_id': ObjectId('5fb316838be90417282b1854'),
#   'DataExtracao': datetime.datetime(2016, 4, 28, 0, 0),
#   'Ano': 2006,
#   'Mes': 3,
#   'CanalEntrada': 'Call Center',
#   'Condicao': 'Nova',
#   'GrupoEconNorm': 'Anatel',
#   'Tipo': 'Pedido de Informação',
#   'Servico': 'Serviços da Anatel',
#   'Modalidade': 'Cópia de Documentos',
#   'Motivo': 'Resposta de solicitação',
#   'UF': 'MG',
#   'QtdeSolic': 1},
#  ...]

# %%
#6) Mostre as contagens de solicitações QtdeSolic por tipo de serviço Servico, em ordem decrescente pelas contagens
parametro3 = [ {"$group": { "_id": {"Servico": "$Servico"}, "count": {"$sum": '$QtdeSolic'}  }}, { "$sort" : { "count" : -1 } } ]
pprint.pprint(list(db.minas.aggregate(parametro3)))
# Out:
# []

# %%
# 7) Mostre todos os documentos com atributo Tipo igual a "Reclamação".
list(db.minas.find({'$Tipo': 'Reclamação'}))
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# <ipython-input-35-041724b1718b> in <module>
#       1 # 7) Mostre todos os documentos com atributo Tipo igual a "Reclamação".
# ----> 2 list(db.minas.find({'$Tipo': 'Reclamação'}))
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1205         if self.__empty:
#    1206             raise StopIteration
# -> 1207         if len(self.__data) or self._refresh():
#    1208             if self.__manipulate:
#    1209                 _db = self.__collection.database
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1122                                   self.__collection.database.client,
#    1123                                   self.__allow_disk_use)
# -> 1124             self.__send_message(q)
#    1125         elif self.__id:  # Get More
#    1126             if self.__limit:
#
# ~\anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     997
#     998         try:
# --> 999             response = client._run_operation_with_response(
#    1000                 operation, self._unpack_response, exhaust=self.__exhaust,
#    1001                 address=self.__address)
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _run_operation_with_response(self, operation, unpack_res, exhaust, address)
#    1366                 unpack_res)
#    1367
# -> 1368         return self._retryable_read(
#    1369             _cmd, operation.read_preference, operation.session,
#    1370             address=address,
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable, exhaust)
#    1469                         # not support retryable reads, raise the last error.
#    1470                         raise last_error
# -> 1471                     return func(session, server, sock_info, slave_ok)
#    1472             except ServerSelectionTimeoutError:
#    1473                 if retrying:
#
# ~\anaconda3\lib\site-packages\pymongo\mongo_client.py in _cmd(session, server, sock_info, slave_ok)
#    1358
#    1359         def _cmd(session, server, sock_info, slave_ok):
# -> 1360             return server.run_operation_with_response(
#    1361                 sock_info,
#    1362                 operation,
#
# ~\anaconda3\lib\site-packages\pymongo\server.py in run_operation_with_response(self, sock_info, operation, set_slave_okay, listeners, exhaust, unpack_res)
#     134                 operation.client._process_response(
#     135                     first, operation.session)
# --> 136                 _check_command_response(
#     137                     first, sock_info.max_wire_version)
#     138         except Exception as exc:
#
# ~\anaconda3\lib\site-packages\pymongo\helpers.py in _check_command_response(response, max_wire_version, msg, allowable_errors, parse_write_concern_error)
#     165
#     166             msg = msg or "%s"
# --> 167             raise OperationFailure(msg % errmsg, code, response,
#     168                                    max_wire_version)
#     169
#
# OperationFailure: unknown top level operator: $Tipo, full error: {'operationTime': Timestamp(1605653285, 6), 'ok': 0.0, 'errmsg': 'unknown top level operator: $Tipo', 'code': 2, 'codeName': 'BadValue', '$clusterTime': {'clusterTime': Timestamp(1605653285, 6), 'signature': {'hash': b'\r\xfc\xa6l\x8d\x0bM\x8b;\x00c\xa8\xd8\x95\x8c4e\x94\xa0\xad', 'keyId': 6895722447887138819}}}

# %%
# 8) Quais diferentes valores encontramos em Tipo?
pprint.pprint(list(db.minas.distinct('Tipo')));
